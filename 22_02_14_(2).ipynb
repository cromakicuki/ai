# %% [markdown]
# <a href="https://colab.research.google.com/github/cromakicuki/ai/blob/main/22_02_14_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Client ID     : Jt1wWFQRDtpzk0tMj3pJ
# Client Secret : amMzDufSaB



import os         # 운영체제 접근
import sys        # 시스템 접근
import requests   # 웹 접근

client_id = "Jt1wWFQRDtpzk0tMj3pJ"
client_secret = "amMzDufSaB"

url = "https://openapi.naver.com/v1/vision/face"     # 얼굴감지
# url = "https://openapi.naver.com/v1/vision/celebrity"  # 유명인 얼굴인식

files = {'image': open('A_Huge_Dog_Family.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":700,"height":521},"faceCount":8},"faces":[{"roi":{"x":303,"y":84,"width":61,"height":61},"landmark":{"leftEye":{"x":318,"y":100},"rightEye":{"x":347,"y":99},"nose":{"x":336,"y":114},"leftMouth":{"x":321,"y":129},"rightMouth":{"x":351,"y":127}},"gender":{"value":"male","confidence":1.0},"age":{"value":"40~44","confidence":0.176157},"emotion":{"value":"neutral","confidence":0.964881},"pose":{"value":"frontal_face","confidence":0.999027}},{"roi":{"x":83,"y":72,"width":66,"height":66},"landmark":null,"gender":{"value":"female","confidence":0.999493},"age":{"value":"35~39","confidence":0.169099},"emotion":{"value":"smile","confidence":0.999899},"pose":{"value":"false_face","confidence":0.846467}},{"roi":{"x":550,"y":79,"width":65,"height":65},"landmark":{"leftEye":{"x":569,"y":92},"rightEye":{"x":598,"y":95},"nose":{"x":582,"y":112},"leftMouth":{"x":565,"y":122},"rightMouth":{"x":594,"y":124}},"gender":{"value":"female","confidence":0.999993},"age":{"value":"28~32","confidence":0.306891},"emotion":{"value":"smile","confidence":0.999789},"pose":{"value":"frontal_face","confidence":0.997157}},{"roi":{"x":468,"y":314,"width":137,"height":137},"landmark":null,"gender":{"value":"female","confidence":0.578422},"age":{"value":"66~70","confidence":0.0529517},"emotion":{"value":"talking","confidence":0.813521},"pose":{"value":"false_face","confidence":0.891699}},{"roi":{"x":340,"y":206,"width":58,"height":58},"landmark":null,"gender":{"value":"male","confidence":0.999964},"age":{"value":"86~90","confidence":0.201173},"emotion":{"value":"talking","confidence":0.954766},"pose":{"value":"false_face","confidence":0.916684}},{"roi":{"x":185,"y":185,"width":61,"height":61},"landmark":null,"gender":{"value":"child","confidence":0.822946},"age":{"value":"43~47","confidence":0.00204982},"emotion":{"value":"talking","confidence":0.994965},"pose":{"value":"false_face","confidence":0.889477}},{"roi":{"x":127,"y":175,"width":50,"height":50},"landmark":null,"gender":{"value":"male","confidence":0.990213},"age":{"value":"58~62","confidence":0.00425248},"emotion":{"value":"talking","confidence":0.952095},"pose":{"value":"false_face","confidence":0.982996}},{"roi":{"x":231,"y":319,"width":91,"height":91},"landmark":null,"gender":{"value":"female","confidence":0.988379},"age":{"value":"32~36","confidence":0.035111},"emotion":{"value":"talking","confidence":0.994362},"pose":{"value":"false_face","confidence":0.975514}}]}

# %%
import json

parsed = json.loads(response.text)

type(parsed)
# Out:
# dict

# %%
print(parsed)
# Out:
# {'info': {'size': {'width': 700, 'height': 521}, 'faceCount': 8}, 'faces': [{'roi': {'x': 303, 'y': 84, 'width': 61, 'height': 61}, 'landmark': {'leftEye': {'x': 318, 'y': 100}, 'rightEye': {'x': 347, 'y': 99}, 'nose': {'x': 336, 'y': 114}, 'leftMouth': {'x': 321, 'y': 129}, 'rightMouth': {'x': 351, 'y': 127}}, 'gender': {'value': 'male', 'confidence': 1.0}, 'age': {'value': '40~44', 'confidence': 0.176157}, 'emotion': {'value': 'neutral', 'confidence': 0.964881}, 'pose': {'value': 'frontal_face', 'confidence': 0.999027}}, {'roi': {'x': 83, 'y': 72, 'width': 66, 'height': 66}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.999493}, 'age': {'value': '35~39', 'confidence': 0.169099}, 'emotion': {'value': 'smile', 'confidence': 0.999899}, 'pose': {'value': 'false_face', 'confidence': 0.846467}}, {'roi': {'x': 550, 'y': 79, 'width': 65, 'height': 65}, 'landmark': {'leftEye': {'x': 569, 'y': 92}, 'rightEye': {'x': 598, 'y': 95}, 'nose': {'x': 582, 'y': 112}, 'leftMouth': {'x': 565, 'y': 122}, 'rightMouth': {'x': 594, 'y': 124}}, 'gender': {'value': 'female', 'confidence': 0.999993}, 'age': {'value': '28~32', 'confidence': 0.306891}, 'emotion': {'value': 'smile', 'confidence': 0.999789}, 'pose': {'value': 'frontal_face', 'confidence': 0.997157}}, {'roi': {'x': 468, 'y': 314, 'width': 137, 'height': 137}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.578422}, 'age': {'value': '66~70', 'confidence': 0.0529517}, 'emotion': {'value': 'talking', 'confidence': 0.813521}, 'pose': {'value': 'false_face', 'confidence': 0.891699}}, {'roi': {'x': 340, 'y': 206, 'width': 58, 'height': 58}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.999964}, 'age': {'value': '86~90', 'confidence': 0.201173}, 'emotion': {'value': 'talking', 'confidence': 0.954766}, 'pose': {'value': 'false_face', 'confidence': 0.916684}}, {'roi': {'x': 185, 'y': 185, 'width': 61, 'height': 61}, 'landmark': None, 'gender': {'value': 'child', 'confidence': 0.822946}, 'age': {'value': '43~47', 'confidence': 0.00204982}, 'emotion': {'value': 'talking', 'confidence': 0.994965}, 'pose': {'value': 'false_face', 'confidence': 0.889477}}, {'roi': {'x': 127, 'y': 175, 'width': 50, 'height': 50}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.990213}, 'age': {'value': '58~62', 'confidence': 0.00425248}, 'emotion': {'value': 'talking', 'confidence': 0.952095}, 'pose': {'value': 'false_face', 'confidence': 0.982996}}, {'roi': {'x': 231, 'y': 319, 'width': 91, 'height': 91}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.988379}, 'age': {'value': '32~36', 'confidence': 0.035111}, 'emotion': {'value': 'talking', 'confidence': 0.994362}, 'pose': {'value': 'false_face', 'confidence': 0.975514}}]}

# %%
print(json.dumps(parsed, indent= 4))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 700,
#             "height": 521
#         },
#         "faceCount": 8
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 303,
#                 "y": 84,
#                 "width": 61,
#                 "height": 61
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 318,
#                     "y": 100
#                 },
#                 "rightEye": {
#                     "x": 347,
#                     "y": 99
#                 },
#                 "nose": {
#                     "x": 336,
#                     "y": 114
#                 },
#                 "leftMouth": {
#                     "x": 321,
#                     "y": 129
#                 },
#                 "rightMouth": {
#                     "x": 351,
#                     "y": 127
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 1.0
#             },
#             "age": {
#                 "value": "40~44",
#                 "confidence": 0.176157
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.964881
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999027
#             }
#         },
#         {
#             "roi": {
#                 "x": 83,
#                 "y": 72,
#                 "width": 66,
#                 "height": 66
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999493
#             },
#             "age": {
#                 "value": "35~39",
#                 "confidence": 0.169099
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.999899
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.846467
#             }
#         },
#         {
#             "roi": {
#                 "x": 550,
#                 "y": 79,
#                 "width": 65,
#                 "height": 65
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 569,
#                     "y": 92
#                 },
#                 "rightEye": {
#                     "x": 598,
#                     "y": 95
#                 },
#                 "nose": {
#                     "x": 582,
#                     "y": 112
#                 },
#                 "leftMouth": {
#                     "x": 565,
#                     "y": 122
#                 },
#                 "rightMouth": {
#                     "x": 594,
#                     "y": 124
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999993
#             },
#             "age": {
#                 "value": "28~32",
#                 "confidence": 0.306891
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.999789
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.997157
#             }
#         },
#         {
#             "roi": {
#                 "x": 468,
#                 "y": 314,
#                 "width": 137,
#                 "height": 137
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.578422
#             },
#             "age": {
#                 "value": "66~70",
#                 "confidence": 0.0529517
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.813521
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.891699
#             }
#         },
#         {
#             "roi": {
#                 "x": 340,
#                 "y": 206,
#                 "width": 58,
#                 "height": 58
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999964
#             },
#             "age": {
#                 "value": "86~90",
#                 "confidence": 0.201173
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.954766
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.916684
#             }
#         },
#         {
#             "roi": {
#                 "x": 185,
#                 "y": 185,
#                 "width": 61,
#                 "height": 61
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.822946
#             },
#             "age": {
#                 "value": "43~47",
#                 "confidence": 0.00204982
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.994965
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.889477
#             }
#         },
#         {
#             "roi": {
#                 "x": 127,
#                 "y": 175,
#                 "width": 50,
#                 "height": 50
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.990213
#             },
#             "age": {
#                 "value": "58~62",
#                 "confidence": 0.00425248
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.952095
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.982996
#             }
#         },
#         {
#             "roi": {
#                 "x": 231,
#                 "y": 319,
#                 "width": 91,
#                 "height": 91
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.988379
#             },
#             "age": {
#                 "value": "32~36",
#                 "confidence": 0.035111
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.994362
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.975514
#             }
#         }
#     ]
# }

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
print(parsed['info'])
# Out:
# {'size': {'width': 700, 'height': 521}, 'faceCount': 8}

# %%
print(parsed['faces'])
# Out:
# [{'roi': {'x': 303, 'y': 84, 'width': 61, 'height': 61}, 'landmark': {'leftEye': {'x': 318, 'y': 100}, 'rightEye': {'x': 347, 'y': 99}, 'nose': {'x': 336, 'y': 114}, 'leftMouth': {'x': 321, 'y': 129}, 'rightMouth': {'x': 351, 'y': 127}}, 'gender': {'value': 'male', 'confidence': 1.0}, 'age': {'value': '40~44', 'confidence': 0.176157}, 'emotion': {'value': 'neutral', 'confidence': 0.964881}, 'pose': {'value': 'frontal_face', 'confidence': 0.999027}}, {'roi': {'x': 83, 'y': 72, 'width': 66, 'height': 66}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.999493}, 'age': {'value': '35~39', 'confidence': 0.169099}, 'emotion': {'value': 'smile', 'confidence': 0.999899}, 'pose': {'value': 'false_face', 'confidence': 0.846467}}, {'roi': {'x': 550, 'y': 79, 'width': 65, 'height': 65}, 'landmark': {'leftEye': {'x': 569, 'y': 92}, 'rightEye': {'x': 598, 'y': 95}, 'nose': {'x': 582, 'y': 112}, 'leftMouth': {'x': 565, 'y': 122}, 'rightMouth': {'x': 594, 'y': 124}}, 'gender': {'value': 'female', 'confidence': 0.999993}, 'age': {'value': '28~32', 'confidence': 0.306891}, 'emotion': {'value': 'smile', 'confidence': 0.999789}, 'pose': {'value': 'frontal_face', 'confidence': 0.997157}}, {'roi': {'x': 468, 'y': 314, 'width': 137, 'height': 137}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.578422}, 'age': {'value': '66~70', 'confidence': 0.0529517}, 'emotion': {'value': 'talking', 'confidence': 0.813521}, 'pose': {'value': 'false_face', 'confidence': 0.891699}}, {'roi': {'x': 340, 'y': 206, 'width': 58, 'height': 58}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.999964}, 'age': {'value': '86~90', 'confidence': 0.201173}, 'emotion': {'value': 'talking', 'confidence': 0.954766}, 'pose': {'value': 'false_face', 'confidence': 0.916684}}, {'roi': {'x': 185, 'y': 185, 'width': 61, 'height': 61}, 'landmark': None, 'gender': {'value': 'child', 'confidence': 0.822946}, 'age': {'value': '43~47', 'confidence': 0.00204982}, 'emotion': {'value': 'talking', 'confidence': 0.994965}, 'pose': {'value': 'false_face', 'confidence': 0.889477}}, {'roi': {'x': 127, 'y': 175, 'width': 50, 'height': 50}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.990213}, 'age': {'value': '58~62', 'confidence': 0.00425248}, 'emotion': {'value': 'talking', 'confidence': 0.952095}, 'pose': {'value': 'false_face', 'confidence': 0.982996}}, {'roi': {'x': 231, 'y': 319, 'width': 91, 'height': 91}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.988379}, 'age': {'value': '32~36', 'confidence': 0.035111}, 'emotion': {'value': 'talking', 'confidence': 0.994362}, 'pose': {'value': 'false_face', 'confidence': 0.975514}}]

# %%
parsed['faces'][4]
# Out:
# {'age': {'confidence': 0.201173, 'value': '86~90'},
#  'emotion': {'confidence': 0.954766, 'value': 'talking'},
#  'gender': {'confidence': 0.999964, 'value': 'male'},
#  'landmark': None,
#  'pose': {'confidence': 0.916684, 'value': 'false_face'},
#  'roi': {'height': 58, 'width': 58, 'x': 340, 'y': 206}}

# %%
import matplotlib.patches as patches  # 사진 수정 관련 모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.pyplot as plt           # 사진(그림) 관련 기본 모듈


img = mpimg.imread('A_Huge_Dog_Family.jpg')     # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10))                      # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                               # 사진틀에 사진 삽입 
print(parsed['faces'][0]['roi'])

x,y,w,h = parsed['faces'][0]['roi'].values()
re_face = patches.Rectangle((x,y),w,h, facecolor = 'none', edgecolor = 'r')
ax.add_patch(re_face)
# Out:
# {'x': 303, 'y': 84, 'width': 61, 'height': 61}

# %%
import matplotlib.patches as patches  # 사진 수정 관련 모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.pyplot as plt           # 사진(그림) 관련 기본 모듈


img = mpimg.imread('A_Huge_Dog_Family.jpg')     # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10))                      # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                               # 사진틀에 사진 삽입 
print(parsed['faces'][0]['roi'])

for each in parsed['faces']:
  x,y,w,h = each['roi'].values()
  re_face = patches.Rectangle((x,y),w,h, facecolor = 'none', edgecolor = 'r')
  ax.add_patch(re_face)
# Out:
# {'x': 303, 'y': 84, 'width': 61, 'height': 61}

# %%
import matplotlib.patches as patches  # 사진 수정 관련 모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.pyplot as plt           # 사진(그림) 관련 기본 모듈


img = mpimg.imread('A_Huge_Dog_Family.jpg')     # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10))                      # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                               # 사진틀에 사진 삽입 
print(parsed['faces'][0]['roi'])

for each in parsed['faces']:
  x,y,w,h = each['roi'].values()
  age,age_conf = each['age'].values()
  gender,gender_conf = each['gender'].values()

  anno = gender + ',' + age
  re_face = patches.Rectangle((x,y),w,h, facecolor = 'none', edgecolor = 'r')

  plt.text(x,y+w,anno,color ='blue')
  ax.add_patch(re_face)
# Out:
# {'x': 303, 'y': 84, 'width': 61, 'height': 61}
